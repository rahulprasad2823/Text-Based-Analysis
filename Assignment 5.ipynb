# %% [markdown]
# ### ASSIGNMENT 5

# %% [markdown]
# ### Read the Dataset

# %%
import pandas as pd
df = pd.read_csv('Amazon_dataset.csv')
df.sample(10)
# Out:
#                         id       asins   brand  \
# 899   AVpfpK8KLJeJML43BCuD  B01BH83OOM  Amazon
# 78    AVpff7_VilAPnD_xc1E_  B00DU15MU4  Amazon
# 360   AVpfLiCSilAPnD_xWpk_  B00CX5P8FC  Amazon
# 324   AVpfLiCSilAPnD_xWpk_  B00CX5P8FC  Amazon
# 169   AV3as-VX-jtxr-f3_PPu  B01LW1MS9C  Amazon
# 1436  AVpge-anilAPnD_xtDVf  B00HX0SRXW  Amazon
# 205   AV1T0_tnvKc47QAVgf2V  B01FWSVGQQ  Amazon
# 1577  AVpfODXeilAPnD_xXeUd  B00LORGAG6  Amazon
# 1123  AVpfpK8KLJeJML43BCuD  B01BH83OOM  Amazon
# 1311  AVpfpK8KLJeJML43BCuD  B01BH83OOM  Amazon
#
#                                              categories colors  \
# 899   Amazon Devices,Home,Smart Home & Connected Liv...  Black
# 78    Categories,Amazon Devices,Streaming Media Players    NaN
# 360   Categories,Amazon Devices,Electronics Features...    NaN
# 324   Categories,Amazon Devices,Electronics Features...    NaN
# 169                                      Amazon Devices    NaN
# ...

# %% [markdown]
# ### Get the Bing Liu lexicon

# %%
from sklearn import preprocessing
import nltk
nltk.download('opinion_lexicon')
from nltk.corpus import opinion_lexicon
from nltk.tokenize import word_tokenize
print('Total number of words in opinion lexicon', len(opinion_lexicon.words()))
print('Examples of positive words in opinion lexicon',
opinion_lexicon.positive()[:10])
print('Examples of negative words in opinion lexicon',
opinion_lexicon.negative()[:10])
# Out:
# Total number of words in opinion lexicon 6789
# Examples of positive words in opinion lexicon ['a+', 'abound', 'abounds', 'abundance', 'abundant', 'accessable', 'accessible', 'acclaim', 'acclaimed', 'acclamation']
# Examples of negative words in opinion lexicon ['2-faced', '2-faces', 'abnormal', 'abolish', 'abominable', 'abominably', 'abominate', 'abomination', 'abort', 'aborted']
# [nltk_data] Downloading package opinion_lexicon to
# [nltk_data]     C:\Users\rahul\AppData\Roaming\nltk_data...
# [nltk_data]   Package opinion_lexicon is already up-to-date!

# %% [markdown]
# ### Create the “Dictionary"

# %%
# Let's create a dictionary which we can use for scoring our review text
nltk.download('punkt')
df.rename(columns={"reviewText": "text"}, inplace=True)
pos_score = 1
neg_score = -1
word_dict = {}
# Adding the positive words to the dictionary
for word in opinion_lexicon.positive():
   word_dict[word] = pos_score
# Adding the negative words to the dictionary
for word in opinion_lexicon.negative():
   word_dict[word] = neg_score
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\rahul\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ### Function to do the math

# %%
def bing_liu_score(text):
    sentiment_score = 0
    bag_of_words = word_tokenize(text.lower())
    for word in bag_of_words:
        if word in word_dict:
            sentiment_score += word_dict[word]
            return sentiment_score

# %% [markdown]
# ### Make sure all texts are non-empty and are type text then call the function

# %%
df['reviews.text'].fillna('no review', inplace=True)
df['Bing_Liu_Score'] = df['reviews.text'].apply(bing_liu_score)
# Out:
# C:\Users\rahul\AppData\Local\Temp\ipykernel_3932\1437731933.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['reviews.text'].fillna('no review', inplace=True)

# %% [markdown]
# ### Display the output

# %%
df[['id',"reviews.text", 'Bing_Liu_Score']].head(10)
# Out:
#                      id                                       reviews.text  \
# 0  AVpe7AsMilAPnD_xQ78G  I initially had trouble deciding between the p...
# 1  AVpe7AsMilAPnD_xQ78G  Allow me to preface this with a little history...
# 2  AVpe7AsMilAPnD_xQ78G  I am enjoying it so far. Great for reading. Ha...
# 3  AVpe7AsMilAPnD_xQ78G  I bought one of the first Paperwhites and have...
# 4  AVpe7AsMilAPnD_xQ78G  I have to say upfront - I don't like coroporat...
# 5  AVpe7AsMilAPnD_xQ78G  My previous kindle was a DX, this is my second...
# 6  AVpe7AsMilAPnD_xQ78G  Allow me to preface this with a little history...
# 7  AVpe7AsMilAPnD_xQ78G  Just got mine right now. Looks the same as the...
# 8  AVpe7AsMilAPnD_xQ78G  I initially had trouble deciding between the p...
# 9  AVpe7AsMilAPnD_xQ78G  I am enjoying it so far. Great for reading. Ha...
#
#    Bing_Liu_Score
# 0            -1.0
# 1             1.0
# 2             1.0
# 3             1.0
# 4             1.0
# 5             1.0
# ...

# %%
df.groupby('id').agg({'Bing_Liu_Score':'mean'})
# Out:
#                       Bing_Liu_Score
# id
# AV000tWuGV-KLJ3ac2-b        1.000000
# AV00l7jV-jtxr-f30lnX        1.000000
# AV00lzP7GV-KLJ3ac0uk        1.000000
# AV00lzd5GV-KLJ3ac0ul        0.428571
# AV1Nik13-jtxr-f31AFO       -0.333333
# ...                              ...
# AVzRloqLGV-KLJ3aavBd        0.703704
# AVzRlpC2vKc47QAVd5FA        1.000000
# AVzRlpC8glJLPUi8FbQA        1.000000
# AVzRlpElvKc47QAVd5FB        1.000000
# AVzRlqklGV-KLJ3aavB0        0.400000
#
# [66 rows x 1 columns]
