# %%
import pandas as pa

# %%
df = pa.read_csv('un-general-debates-blueprint.csv')

# %% [markdown]
# ## Let’s start with an overview:

# %%
df.head()
# Out:
#    session  year country country_name             speaker position  \
# 0       25  1970     ALB      Albania             Mr. NAS      NaN
# 1       25  1970     ARG    Argentina  Mr. DE PABLO PARDO      NaN
# 2       25  1970     AUS    Australia         Mr. McMAHON      NaN
# 3       25  1970     AUT      Austria  Mr. KIRCHSCHLAEGER      NaN
# 4       25  1970     BEL      Belgium          Mr. HARMEL      NaN
#
#                                                 text
# 0  33: May I first convey to our President the co...
# 1  177.\t : It is a fortunate coincidence that pr...
# 2  100.\t  It is a pleasure for me to extend to y...
# 3  155.\t  May I begin by expressing to Ambassado...
# 4  176. No doubt each of us, before coming up to ...

# %%
df.columns
# Out:
# Index(['session', 'year', 'country', 'country_name', 'speaker', 'position',
#        'text'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7507 entries, 0 to 7506
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   session       7507 non-null   int64
#  1   year          7507 non-null   int64
#  2   country       7507 non-null   object
#  3   country_name  7507 non-null   object
#  4   speaker       7480 non-null   object
#  5   position      4502 non-null   object
#  6   text          7507 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 410.7+ KB

# %%
df.describe()
# Out:
#            session         year
# count  7507.000000  7507.000000
# mean     49.610763  1994.610763
# std      12.892155    12.892155
# min      25.000000  1970.000000
# 25%      39.000000  1984.000000
# 50%      51.000000  1996.000000
# 75%      61.000000  2006.000000
# max      70.000000  2015.000000

# %%
df.dtypes
# Out:
# session          int64
# year             int64
# country         object
# country_name    object
# speaker         object
# position        object
# text            object
# dtype: object

# %% [markdown]
# ## Stats about text fields

# %%
df.describe(include='O')
# Out:
#        country country_name        speaker                      position  \
# count     7507         7507           7480                          4502
# unique     199          199           5428                           113
# top        ALB      Albania  Seyoum Mesfin  Minister for Foreign Affairs
# freq        46           46             12                          1813
#
#                                                      text
# count                                                7507
# unique                                               7507
# top     33: May I first convey to our President the co...
# freq                                                    1

# %% [markdown]
# ## Check for missing data

# %%
df.isna().sum()
# Out:
# session            0
# year               0
# country            0
# country_name       0
# speaker           27
# position        3005
# text               0
# dtype: int64

# %% [markdown]
# ## Let us fill the missing data

# %%
df['speaker'].fillna('unknown', inplace=True)

# %%
df['position'].fillna('unknown', inplace=True)

# %%
df.isna().sum()
# Out:
# session         0
# year            0
# country         0
# country_name    0
# speaker         0
# position        0
# text            0
# dtype: int64

# %% [markdown]
# ## Now uppercase (or lowercase) alltext

# %%
df[df['speaker'].str.contains('BUSH')]
# Out:
#       session  year country   country_name          speaker   position  \
# 2876       45  1990     USA  United States      GEORGE BUSH    unknown
# 3207       47  1992     USA  United States  Mr. George BUSH  President
#
#                                                    text
# 2876  ﻿\nIt is really a great privilege to greet you...
# 3207  Forty-seven years ago I was a young man of 21,...

# %%
df[df['speaker'].str.contains('PARDO')]
# Out:
#     session  year country country_name             speaker position  \
# 1        25  1970     ARG    Argentina  Mr. DE PABLO PARDO  unknown
# 72       26  1971     ARG    Argentina  Mr. DE PABLO PARDO  unknown
#
#                                                  text
# 1   177.\t : It is a fortunate coincidence that pr...
# 72  33.\t On behalf of the Argentine Government I ...

# %%
df[df['speaker'].str.contains('KIRCHSCHLAEGER')]
# Out:
#     session  year country country_name             speaker position  \
# 3        25  1970     AUT      Austria  Mr. KIRCHSCHLAEGER  unknown
# 74       26  1971     AUT      Austria  Mr. KIRCHSCHLAEGER  unknown
#
#                                                  text
# 3   155.\t  May I begin by expressing to Ambassado...
# 74  112.\t  Mr. President. I am happy to convey to...

# %%
df[df['speaker'].str.contains('BUSH')]
# Out:
#       session  year country   country_name          speaker   position  \
# 2876       45  1990     USA  United States      GEORGE BUSH    unknown
# 3207       47  1992     USA  United States  Mr. George BUSH  President
#
#                                                    text
# 2876  ﻿\nIt is really a great privilege to greet you...
# 3207  Forty-seven years ago I was a young man of 21,...

# %%
df['length'] = df['text'].str.len()

# %%
df['length'].plot(kind='hist', bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
import seaborn as sns
where = df['country'].isin(['USA', 'FRA', 'GBR', 'CHN', 'RUS'])
g = sns.catplot(data=df[where], x="country", y="length", kind='box')
g.fig.set_size_inches(10, 8) ###

# %%
df['length'].plot()
# Out:
# <Axes: >

# %%
df['length'].plot(kind='box', vert=False)
# Out:
# <Axes: >

# %% [markdown]
# ## Regex

# %% [markdown]
# ## Function to tokenize:

# %%
import regex as re
def tokenize(text):
    return re.findall(r'[\w-]*[a-z|A-Z][\w-]*', text)
    testtext = "Let's defeat SARS-CoV-2 together in 2020! www.cdc.gov"
testtokens = tokenize(testtext)
print(testtokens)
# Out:
# ['Let', 's', 'defeat', 'SARS-CoV-2', 'together', 'in', 'www', 'cdc', 'gov']

# %% [markdown]
# ## How to Remove stop words

# %%
import nltk
nltk.download('stopwords')
stopwords = set(nltk.corpus.stopwords.words('english'))
print(stopwords)
# Out:
# {"you'd", 'it', 'on', 're', 'such', 'myself', 'shouldn', 'do', 'through', 'itself', 'theirs', 'then', 'if', 'his', 'has', 'am', 'that', 'because', 't', 'does', 'down', 'but', 'them', 'how', 'what', 'themselves', "wouldn't", 'from', 'had', 'before', 'again', 'nor', 'once', 'yourself', "won't", 'doesn', 'as', "you've", 'o', 'to', 'her', 'here', 'not', 'until', 'yourselves', 'their', 'mightn', "isn't", 'wasn', 'in', "didn't", "hasn't", 'a', 'ain', 'herself', 'hers', 's', 'will', 'needn', 'an', 'with', 'our', 'whom', "hadn't", 'under', 'why', 'those', 'him', 'being', 'and', 'where', 'this', "wasn't", 'these', 'when', "doesn't", 'some', 'were', 'll', "it's", 'too', 'he', 'hadn', 'which', "needn't", 'below', 'more', 'isn', 'so', "mightn't", 'while', "you're", 'against', 'there', 'further', 'between', 'most', 'can', 'up', 'of', "don't", "you'll", 'all', 'very', 'is', 'ours', 'did', 'y', 'should', 'haven', 'i', "mustn't", "shan't", 'off', 'me', 'its', 'for', 'at', 'aren', "she's", 'ourselves', 'was', 'are', 'few', 'into', 'didn', 'weren', 'we', "weren't", 'during', 'shan', 'been', 'they', 'you', 'about', 'won', 'own', 'or', 'now', 'my', 'any', 'wouldn', 'yours', 'your', "that'll", 'over', 'don', 'doing', "couldn't", 'having', 'she', 'both', 'only', 'be', 'have', "should've", 'hasn', 'the', 'no', "aren't", 'other', 'mustn', "haven't", 'ma', 'above', 'than', 'just', 've', 'same', 'who', 'each', "shouldn't", 'after', 'm', 'out', 'd', 'by', 'himself', 'couldn'}
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/puttasathvik/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# ## Function to remove stop words

# %%
def remove_stop(tokens, stopwords):
    if not isinstance(tokens, list):
        raise ValueError("Input tokens must be a list")
    return [t for t in tokens if t.lower() not in stopwords]

# Just testing it
testtokens = ["This", "is", "a", "test", "sentence"]
stopwords = ["is", "a"]

cleantokens = remove_stop(testtokens, stopwords)
print(cleantokens)
# Out:
# ['This', 'test', 'sentence']

# %% [markdown]
# ## Let’s make a “pipeline”

# %%
pipeline = [str.lower, tokenize, remove_stop]

def prepare(text, pipeline, stopwords):
    tokens = text
    for fun in pipeline:
        if fun == remove_stop:  # Check if the current function is remove_stop
            tokens = fun(tokens, stopwords)  # Pass stopwords to remove_stop
        else:
            tokens = fun(tokens)
    return tokens

# Example usage:
text = "This is a sample text."
stopwords = ["is", "a"]
processed_text = prepare(text, pipeline, stopwords)
print(processed_text)
# Out:
# ['this', 'sample', 'text']

# %% [markdown]
# ## Run the pipeline

# %%
def process_text(text, pipeline, stopwords):
    for func in pipeline:
        if func == remove_stop:
            text = func(text, stopwords)
        else:
            text = func(text)
    return text

# Example usage:
df['tokens'] = df['text'].apply(process_text, pipeline=pipeline, stopwords=stopwords)

# %% [markdown]
# ## Count the tokens

# %%
df['num_tokens'] = df['tokens'].map(len)
df.tail()
# Out:
#       session  year country  country_name                            speaker  \
# 7502       70  2015     YEM         Yemen  Mr. Abdrabuh Mansour Hadi Mansour
# 7503       70  2015     YUG    Yugoslavia               Mr. Tomislav Nikolić
# 7504       70  2015     ZAF  South Africa                         Jacob Zuma
# 7505       70  2015     ZMB        Zambia             Mr. Edgar Chagwa Lungu
# 7506       70  2015     ZWE      Zimbabwe                      Robert Mugabe
#
#        position                                               text  length  \
# 7502  President  On behalf of the people and the Government of ...   10568
# 7503  President  \nSeventy years have passed since the establis...   25430
# 7504  President  I should like to congratulate the President an...   13662
# 7505  President  I would like to begin by thanking the Secretar...   14247
# 7506  President  Allow me at the outset to extend to Mr. Mogens...   11013
#
#                                                  tokens  num_tokens
# 7502  [on, behalf, of, the, people, and, the, govern...        1653
# 7503  [seventy, years, have, passed, since, the, est...        4023
# 7504  [i, should, like, to, congratulate, the, presi...        2107
# 7505  [i, would, like, to, begin, by, thanking, the,...        2141
# 7506  [allow, me, at, the, outset, to, extend, to, m...        1703

# %% [markdown]
# ## Word frequencyAnalysis

# %% [markdown]
# ## Easy! Use the “Counter”

# %%
from collections import Counter
tokens = tokenize("She likes my cats and my cats like my sofa.")
testcount= Counter(tokens)
print(testcount)
# Out:
# Counter({'my': 3, 'cats': 2, 'She': 1, 'likes': 1, 'and': 1, 'like': 1, 'sofa': 1})

# %% [markdown]
# ## You can also add new data to the currentcount:

# %%
more_tokens = tokenize("She likes dogs and cats.")
testcount.update(more_tokens)
print(testcount)
# Out:
# Counter({'my': 3, 'cats': 3, 'She': 2, 'likes': 2, 'and': 2, 'like': 1, 'sofa': 1, 'dogs': 1})

# %% [markdown]
# ## Let’s count:

# %%
counter = Counter()
df['tokens'].map(counter.update)
print(counter.most_common(5))
# Out:
# [('the', 1899342), ('of', 1157244), ('and', 796563), ('to', 734634), ('in', 523189)]

# %% [markdown]
# ## Now, we put the word frequency in it’s owndataframe for analysis

# %%
freq_df = pd.DataFrame.from_dict(counter,orient='index', columns=['freq'])
freq_df = freq_df.query('freq >= 1')
freq_df.index.name = 'token'
#Sort and display!
freq_df = freq_df.sort_values('freq', ascending=False)
freq_df.head(10)
# Out:
#           freq
# token
# the    1899342
# of     1157244
# and     796563
# to      734634
# in      523189
# that    314521
# for     230185
# we      220322
# on      164103
# this    140665

# %% [markdown]
# ## Stats!

# %%
freq_df.describe()
# Out:
#                freq
# count  6.844600e+04
# mean   3.033591e+02
# std    1.015913e+04
# min    1.000000e+00
# 25%    1.000000e+00
# 50%    2.000000e+00
# 75%    1.500000e+01
# max    1.899342e+06

# %% [markdown]
# ## Bar chart

# %%
ax = freq_df.head(15).plot(kind='barh', width=0.95, figsize=(12,8))
ax.invert_yaxis()
ax.set(xlabel='Frequency', ylabel='Token', title='Top Words')
# Out:
# [Text(0.5, 0, 'Frequency'), Text(0, 0.5, 'Token'), Text(0.5, 1.0, 'Top Words')]

# %% [markdown]
# ## Word cloud

# %%
from wordcloud import WordCloud
from matplotlib import pyplot as plt
text = df.query("year==2015 and country=='USA'")['text'].values[0]
plt.figure(figsize=(14, 7)) ###
wc = WordCloud(max_words=100, stopwords=stopwords)
wc.generate(text)
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %% [markdown]
# ## My style  (ALL data)

# %%
from wordcloud import WordCloud  # Import the WordCloud class
import matplotlib.pyplot as plt  # Import the pyplot module from matplotlib

# Create a WordCloud object with specified parameters
wc = WordCloud(
    background_color='white',  # Set background color to white
    width=300,                 # Set width of the word cloud image
    height=300,                # Set height of the word cloud image
    max_words=100,             # Maximum number of words to include in the word cloud
    margin=2                   # Set margin between words
)

# Generate the word cloud using the frequency dictionary
wc.fit_words(freq_df['freq'].to_dict())

# Create a new figure for the plot with specified size and no specific background color
plt.figure(figsize=(8, 8), facecolor=None)

# Display the word cloud image
plt.imshow(wc)

# Turn off axis labels
plt.axis("off")

# Adjust layout to eliminate extra whitespace
plt.tight_layout(pad=0)

# Show the plot
plt.show()
